# %%
import simpful as sf
from sklearn.datasets import load_iris
import pandas as pd
data = load_iris()
iris = pd.DataFrame(data.data, columns=data.feature_names)
iris['class'] = pd.Series(data.target)
iris.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  class
# 0                5.1               3.5                1.4               0.2      0
# 1                4.9               3.0                1.4               0.2      0
# 2                4.7               3.2                1.3               0.2      0
# 3                4.6               3.1                1.5               0.2      0
# 4                5.0               3.6                1.4               0.2      0

# %%
iris.columns = [x.replace(' (cm)', '').replace(' ', '_') for x in iris.columns]

# %%
import numpy as np

# %%
# %%bash
# xdotool getactivewindow key ctrl+s
